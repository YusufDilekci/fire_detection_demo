# %% [markdown]
# <a href="https://colab.research.google.com/github/YusufDilekci/fire_detection_demo/blob/main/TrainYolov8FireDatasetTrail.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install roboflow

from roboflow import Roboflow
import os
import shutil

rf = Roboflow(api_key="uCpOU3hPCUpRwDCWOuyl")
project = rf.workspace("bitirme-projesi-4ldgp").project("fire-nwk93")
version = project.version(2)
dataset = version.download("yolov8")

source_path = dataset.location


target_directory = "/content/dataset/"


if not os.path.exists(target_directory):
    os.makedirs(target_directory)

shutil.move(source_path, target_directory)
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# [WARNING] we noticed you are downloading a `yolov8` datasets but you don't have `ultralytics` installed. Roboflow `.deploy` supports only models trained with `ultralytics==8.0.196`, to intall it `pip install ultralytics==8.0.196`.
# '/content/dataset/Fire-2'

# %%
''' My Drivedan dosyalari cekmek icin kullanıilacak'''

from google.colab import drive

drive.mount('/content/gdrive')

ROOT_DIR = '/content/gdrive/MyDrive/fire_dataset'
# Out:
# Mounted at /content/gdrive

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 870.5/870.5 kB 34.7 MB/s eta 0:00:00
# ...

# %%
import os
from ultralytics import YOLO


# Load a pre-trained YOLO model (you can choose n, s, m, l, or x versions)
model = YOLO("yolov8n.pt")

DATA_DIR = '/content/dataset/Fire-2'

# Start training on your custom dataset
model.train(data=os.path.join(DATA_DIR, "data.yaml"), epochs=50, imgsz=640)
# Out:
# Ultralytics 8.3.13 🚀 Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
import locale
print(locale.getpreferredencoding())
# Out:
# ANSI_X3.4-1968

# %%
def getpreferredencoding(do_setlocale = True):
    return "UTF-8"
locale.getpreferredencoding = getpreferredencoding

# %%
# !yolo predict model=/content/runs/detect/train5/weights/best.pt source=/content/dataset/Fire-2/test/images imgsz=640
# Out:
# Ultralytics 8.3.13 🚀 Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 186 layers, 2,685,148 parameters, 0 gradients, 6.8 GFLOPs
#
# image 1/120 /content/dataset/Fire-2/test/images/efi_102_png.rf.d3cc49fb3ccd0ca5ecf244b706028f36.jpg: 640x640 1 Fire, 9.6ms
# image 2/120 /content/dataset/Fire-2/test/images/efi_118_png.rf.600a76b759db2897b8b3cafb31e2bcf4.jpg: 640x640 1 Fire, 7.5ms
# image 3/120 /content/dataset/Fire-2/test/images/efi_126_png.rf.c1628a9aadfa021abb5643030687f0d5.jpg: 640x640 1 Fire, 7.2ms
# image 4/120 /content/dataset/Fire-2/test/images/efi_128_png.rf.6eae17b409415f6ea2f3866606abcc1b.jpg: 640x640 1 Fire, 7.4ms
# image 5/120 /content/dataset/Fire-2/test/images/efi_137_png.rf.3e2ef1a2b8587c0e3fd46572d1e4f7c0.jpg: 640x640 1 Fire, 7.7ms
# image 6/120 /content/dataset/Fire-2/test/images/efi_15_png.rf.bad43cc8358952666845b268509ce051.jpg: 640x640 1 Fire, 8.4ms
# ...

# %%
import glob
from IPython.display import Image, display

Image(filename='/content/runs/detect/predict/pefi_82_png.rf.be24fa1f936806139f5dc6d074eb2a7c.jpg')

# %%
for image_path in glob.glob(f'/content/runs/detect/predict/*.jpg')[:2]:
  display(Image(filename=image_path, height=500))
  print('\n')

# %%
os.system('cp -r /content/runs /content/gdrive/MyDrive/fire_dataset')
# Out:
# 0
